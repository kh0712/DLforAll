# %%
import tensorflow as tf
import numpy as np

# %%
X = np.array([1, 2, 3])
Y = np.array([1, 2, 3])

def cost_func(W, X, Y):
  hypothesis = X * W
  return tf.reduce_mean(tf.square(hypothesis - Y))

# W와 cost의 변화를 함께 보자.
W_values = np.linspace(-3, 5, num=15)
cost_values = []

for feed_W in W_values:
    curr_cost = cost_func(feed_W, X, Y)
    cost_values.append(curr_cost)
    print("{:6.3f} | {:10.5f}".format(feed_W, curr_cost))
# Out:
# -3.000 |   74.66667
# -2.429 |   54.85714
# -1.857 |   38.09524
# -1.286 |   24.38095
# -0.714 |   13.71429
# -0.143 |    6.09524
#  0.429 |    1.52381
#  1.000 |    0.00000
#  1.571 |    1.52381
#  2.143 |    6.09524
#  2.714 |   13.71429
#  3.286 |   24.38095
#  3.857 |   38.09524
#  4.429 |   54.85714
#  5.000 |   74.66667

# %%
x_data = [1., 2., 3., 4.]
y_data = [1., 3., 5., 7.]

W = tf.Variable(tf.random.normal((1,), -100., 100.))

for step in range(300):
    hypothesis = W * x_data
    cost = tf.reduce_mean(tf.square(hypothesis - y_data))

    alpha = 0.01 # learning rate
    
    #cost func = 1/(2m) * mean((w*x - y)^2)
    #cost func에 대한 w 편미분 : 1/m * mean((w*x-y)x)
    gradient = tf.reduce_mean(tf.multiply(tf.multiply(W, X) - Y, X))
    
    
    descent = W - tf.multiply(alpha, gradient)
    W.assign(descent)
    
    if step % 10 == 0:
        print('{:5} | {:10.4f} | {:10.6f}'.format(
            step, cost.numpy(), W.numpy()[0]))
# Out:
#     0 |   893.4444 |  14.190923
#    10 |   343.5288 |   9.179429
#    20 |   132.0866 |   6.071901
#    30 |    50.7872 |   4.144985
#    40 |    19.5277 |   2.950143
#    50 |     7.5084 |   2.209244
#    60 |     2.8870 |   1.749828
#    70 |     1.1100 |   1.464954
#    80 |     0.4268 |   1.288309
#    90 |     0.1641 |   1.178774
#   100 |     0.0631 |   1.110854
#   110 |     0.0243 |   1.068739
#   120 |     0.0093 |   1.042623
#   130 |     0.0036 |   1.026430
#   140 |     0.0014 |   1.016389
#   150 |     0.0005 |   1.010162
#   160 |     0.0002 |   1.006301
#   170 |     0.0001 |   1.003907
#   180 |     0.0000 |   1.002423
#   190 |     0.0000 |   1.001502
#   200 |     0.0000 |   1.000932
#   210 |     0.0000 |   1.000578
#   220 |     0.0000 |   1.000358
#   230 |     0.0000 |   1.000222
#   240 |     0.0000 |   1.000138
#   250 |     0.0000 |   1.000085
#   260 |     0.0000 |   1.000053
#   270 |     0.0000 |   1.000033
#   280 |     0.0000 |   1.000020
#   290 |     0.0000 |   1.000013
