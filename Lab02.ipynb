# %%
import tensorflow as tf

# %%
x = range(1,6)
y = range(1,6)

# %%
W = tf.Variable(2.7)
b = tf.Variable(0.5)

# %%
lr = 0.01

# %%
for i in range(0,2001):
    with tf.GradientTape() as tape:
        hypo = W*x + b
        cost = tf.reduce_mean(tf.square(hypo -y))
    
    #cost function에 대해 W와 b에 대한 미분값을 계산해준다.
    W_grad, b_grad = tape.gradient(cost, [W, b])
    W.assign_sub(lr*W_grad)
    b.assign_sub(lr*b_grad)
    if i % 500 == 0:
        print("{:5}|{:10.4f}|{:10.4f}|{:10.6f}".format(i,W.numpy(),b.numpy(),cost))
# Out:
#     0|    1.0000|    0.0000|  0.000000
#   500|    1.0000|    0.0000|  0.000000
#  1000|    1.0000|    0.0000|  0.000000
#  1500|    1.0000|    0.0000|  0.000000
#  2000|    1.0000|    0.0000|  0.000000

# %% [markdown]
# Gradient decent -> Global min 보장해주지 않는다.
